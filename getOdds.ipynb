# %%
import urllib.request
import urllib.parse
import time
import json
import pandas as pd
import seaborn as sns

# %%
url = 'https://oldrace.netkeiba.com/?pid=show_ninkioddsgraph_js&raceid=201905050811&type={0}&offset=0&limit=5000'
ngscore = 0
base_score = 100000000000000

# %%
def santan(url):

    url = url.format('8')

    try:

        with urllib.request.urlopen(url) as f:
            res =json.loads( f.read().decode('utf-8') )

        score = base_score
        score_arr = [0] * len(umalist)

        for odd in res['showArray']:
            kumi = odd['Kumi'].split('-')
            score_arr[int(kumi[0]) - 1]+=score
            score -= 1
            score_arr[int(kumi[1]) - 1]+=score
            score -= 1
            score_arr[int(kumi[2]) - 1]+=score
            score -= 1
        
        score_arr = [ngscore if i == 0 else i for i in score_arr]
        df = pd.DataFrame(data={'3tan':score_arr}, columns=['3tan'])
        return df.rank(ascending=False).astype(int)


    except Exception as e:
        print(e)
        return []

# %%
def sanhuku(url):
 
    url = url.format('7')
    try:

        with urllib.request.urlopen(url) as f:
            res =json.loads( f.read().decode('utf-8') )

        score = base_score
        score_arr = [0] * len(umalist)

        for odd in res['showArray']:
            kumi = odd['Kumi'].split('-')
            score_arr[int(kumi[0]) - 1]+=score
            score_arr[int(kumi[1]) - 1]+=score
            score_arr[int(kumi[2]) - 1]+=score
            score -= 1
        
        score_arr = [ngscore if i == 0 else i for i in score_arr]
        df = pd.DataFrame(data={'3huku':score_arr}, columns=['3huku'])
        return df.rank(ascending=False).astype(int)

    except Exception as e:
        print(e)
        return []

# %%
def umatan(url):
 
    url = url.format('6')

    try:

        with urllib.request.urlopen(url) as f:
            res =json.loads( f.read().decode('utf-8') )
        
        score = base_score
        score_arr = [0] * len(umalist)
        
        for odd in res['showArray']:
            kumi = odd['Kumi'].split('-')
            score_arr[int(kumi[0]) - 1]+=score
            score -= 1
            score_arr[int(kumi[1]) - 1]+=score
            score -= 1

        score_arr = [ngscore if i == 0 else i for i in score_arr]
        df = pd.DataFrame(data={'umatan':score_arr}, columns=['umatan'])
        return df.rank(ascending=False).astype(int)

    except Exception as e:
        print(e)
        return []

# %%
def wide(url):
 
    url = url.format('5')

    try:

        with urllib.request.urlopen(url) as f:
            res =json.loads( f.read().decode('utf-8') )
            
        score = base_score
        score_arr = [0] * len(umalist)

        for odd in res['showArray']:
            kumi = odd['Kumi'].split('-')
            score_arr[int(kumi[0]) - 1]+=score
            score_arr[int(kumi[1]) - 1]+=score
            score -= 1
        
        score_arr = [ngscore if i == 0 else i for i in score_arr]
        df = pd.DataFrame(data={'wide':score_arr}, columns=['wide'])
        return df.rank(ascending=False).astype(int)

    except Exception as e:
        print(e)
        return []

# %%
def umaren(url):
  
    url = url.format('4')

    try:

        with urllib.request.urlopen(url) as f:
            res =json.loads( f.read().decode('utf-8') )

        score = base_score
        score_arr = [0] * len(umalist)
        
        for odd in res['showArray']:
            kumi = odd['Kumi'].split('-')
            score_arr[int(kumi[0]) - 1]+=score
            score_arr[int(kumi[1]) - 1]+=score
            score -= 1
        
        score_arr = [ngscore if i == 0 else i for i in score_arr]
        
        df = pd.DataFrame(data={'umaren':score_arr}, columns=['umaren'])
        return df.rank(ascending=False).astype(int)

    except Exception as e:
        print(e)
        return []

# %%
def tanhuku(url):
 
    url = url.format('1')
    try:

        with urllib.request.urlopen(url) as f:
            res =json.loads( f.read().decode('utf-8') )

        o1 = []
        for odd in res['showArray']:
            o1.append(odd['Kumi'])

        umalist = sorted(o1)

        score = 1
        score_arr = [0] * len(umalist)
        for o in o1:
            score_arr[o - 1] = score
            score = score + 1

        return umalist, score_arr


    except Exception as e:
        print(e)
        return [],[]

# %%
(umalist, tan) = tanhuku(url)
df = pd.DataFrame(data={
    'umaban':umalist, 
    'tanhuku':tan, 
}, columns=[
    'umaban',
    'tanhuku',
])
df2 = df.join(umaren(url)).join(wide(url)).join(umatan(url)).join(sanhuku(url)).join(santan(url))

cm = sns.light_palette("#2ecc71", as_cmap=True)
df2.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col0 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col1 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col2 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col3 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col4 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col5 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row0_col6 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col0 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col1 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col2 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col3 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col4 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col5 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row1_col6 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col0 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col1 {
#             background-color:  #2ecc71;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col2 {
#             background-color:  #2ecc71;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col3 {
#             background-color:  #2ecc71;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col4 {
#             background-color:  #2ecc71;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col5 {
#             background-color:  #2ecc71;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row2_col6 {
#             background-color:  #2ecc71;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col0 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col1 {
#             background-color:  #9ae7ba;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col2 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col3 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col4 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col5 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row3_col6 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col0 {
#             background-color:  #b4edcc;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col1 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col2 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col3 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col4 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col5 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row4_col6 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col0 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col1 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col2 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col3 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col4 {
#             background-color:  #d0f4df;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col5 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row5_col6 {
#             background-color:  #c2f1d6;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col0 {
#             background-color:  #9ae7ba;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col1 {
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col2 {
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col3 {
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col4 {
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col5 {
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row6_col6 {
#             background-color:  #3bcf7a;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col0 {
#             background-color:  #8ce3b1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col1 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col2 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col3 {
#             background-color:  #eafaf1;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col4 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col5 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row7_col6 {
#             background-color:  #ddf7e8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row8_col0 {
#             background-color:  #7ee0a8;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row8_col1 {
#             background-color:  #a7eac3;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row8_col2 {
#             background-color:  #9ae7ba;
#             color:  #000000;
#         }    #T_7bef05a4_4afa_11ea_9389_acde48001122row8_col3 {
#             background-color:  #8ce3b1;
#             color:  #000000;

# %%
print(df2.to_html())
